# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
internship = pd.read_excel('Analyse Stages Data.xlsx','Feuil1',index_col=[0,1,2])
internship.head()
# Out:
#                                              Volvo  \
# domain      sub-domain Description
# link        NaN        NaN                     NaN
# offer       NaN        NaN                linkedin
# job         NaN        NaN          Data Scientist
# sector      NaN        NaN              Automotive
# probability NaN        NaN                     NaN
#
#                                                                          Emerton Data  \
# domain      sub-domain Description
# link        NaN        NaN          https://www.linkedin.com/jobs/view/double-trac...
# offer       NaN        NaN                                                   linkedin
# job         NaN        NaN                                             Data scientist
# sector      NaN        NaN                                                 consulting
# probability NaN        NaN                                                        NaN
#
# ...

# %%
# transposition pour avoir les stages en ligne
internship = internship.T
internship.head()
# Out:
# domain                                                       link     offer  \
# sub-domain                                                    NaN       NaN
# Description                                                   NaN       NaN
# Volvo                                                         NaN  linkedin
# Emerton Data    https://www.linkedin.com/jobs/view/double-trac...  linkedin
# Smart AdServer  https://www.linkedin.com/jobs/view/data-scient...  linkedin
# Doctolib        https://www.linkedin.com/jobs/view/data-engine...  linkedin
# TRIMANE         https://www.indeed.fr/voir-emploi?jk=2e06692b5...    Indeed
#
# domain                     job             sector probability   statistics  \
# sub-domain                 NaN                NaN         NaN Not precised
# Description                NaN                NaN         NaN          NaN
# Volvo           Data Scientist         Automotive         NaN          NaN
# ...

# %%
# creer / visualiser les indexs
internship.columns[0:50]
# Out:
# MultiIndex([(                   'link',                nan, ...),
#             (                  'offer',                nan, ...),
#             (                    'job',                nan, ...),
#             (                 'sector',                nan, ...),
#             (            'probability',                nan, ...),
#             (             'statistics',     'Not precised', ...),
#             (             'statistics',      'time series', ...),
#             (             'statistics',        '"vanille"', ...),
#             (             'statistics',       'regression', ...),
#             (             'statistics',        'stocastic', ...),
#             (             'statistics',  'statistic tests', ...),
#             (             'statistics',    'random forest', ...),
#             (             'statistics',             'SPSS', ...),
#             (       'machine learning',     'Not precised', ...),
# ...

# %% [markdown]
# ## Internship analyse by web site providing the offers

# %%
offre = internship['offer'] 
offre = offre.iloc[:,0] 
offre.head()
offre.str.lower().value_counts()
# Out:
# indeed      31
# linkedin    15
# Name: (nan, nan), dtype: int64

# %%
labels = offre.str.lower().value_counts().index
sizes = offre.str.lower().value_counts()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  

plt.show()

# %% [markdown]
# ## Internship analyse by company type

# %%
sector = internship['sector']
sector = sector.iloc[:,0]
sector.head()
# Out:
# Volvo                    Automotive
# Emerton Data             consulting
# Smart AdServer    digital marketing
# Doctolib               Web solution
# TRIMANE                  consulting
# Name: (nan, nan), dtype: object

# %%
labels = sector.str.lower().value_counts().index
sizes = sector.str.lower().value_counts()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,
        shadow=True, startangle=180)
ax1.axis('equal')  

plt.show()

# %% [markdown]
# ## Internship analyse by job type

# %%
job = internship['job']
job = job.iloc[:,0]
job.head()
# Out:
# Volvo             Data Scientist
# Emerton Data      Data scientist
# Smart AdServer    Data scientist
# Doctolib           data engineer
# TRIMANE           data scientist
# Name: (nan, nan), dtype: object

# %%
labels = job.str.lower().value_counts().index
sizes = job.str.lower().value_counts()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,autopct='%1.1f%%',
        shadow=True, startangle=200)
ax1.axis('equal')  

plt.show()

# %%
lang = internship['Language'].count().sort_values()
lang = lang[lang >=2]
lang_idx = lang.index.droplevel(level=['Description'])
lang
# Out:
# sub-domain    Description
# Matlab        language          2
# Keras         language          2
# API Rest      language          2
# TensorFlow    language          3
# VBA           language          3
# Not precised  Datawarehouse     5
# Scala         language          5
# Object        language          6
# Java          language          6
# Excel         language          8
# R             language         12
# SQL           language         15
# Python        language         33
# dtype: int64

# %%
labels = lang_idx
sizes = lang

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,
        shadow=True, startangle=175)
ax1.axis('equal')  

plt.show()

# %%
quality = internship['Qualities'].count().sort_values()
#quality = quality[quality >= 5]
#quality_idx = quality.index.droplevel(level=['Description'])
quality = quality[quality.rank(ascending=False, method='max') <= 12]
quality_idx = quality.index.droplevel(level=['Description'])

# %%
labels = quality_idx
sizes = quality

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,
        shadow=True, startangle=175)
ax1.axis('equal')  

plt.show()
